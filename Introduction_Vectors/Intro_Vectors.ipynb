# %% [markdown]
# Name: Sheena Stella A. Salde <br>
#     CS 3103: Discrete Mathematics 3

# %% [markdown]
# ## Prove:
# Prove that $-1 \leq \frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}||\ ||\textbf{v}||} \leq 1$.

# %% [markdown]
# ## Assigment:

# %% [markdown]
# #### MANUAL SOLUTION No. 1:
# 1. Let $\textbf{u} = (1, -2, 4)$ and $\textbf{v} = (3,5,1)$ $\textbf{w} = (2,1,-3)$ find:<br>
# a. $3\textbf{u}-2\textbf{v}$<br>
# $$
# \begin{align}
# 3u\ -\ 2v\ =\ 3\left[\begin{matrix}1\\-2\\4\\\end{matrix}\right]-\ 2\left[\begin{matrix}3\\5\\1\\\end{matrix}\right]\ =\ \left[\begin{matrix}3\\-6\\12\\\end{matrix}\right]-\ \left[\begin{matrix}6\\10\\2\\\end{matrix}\right]\ =\ \left[\begin{matrix}-3\\-16\\10\\\end{matrix}\right]
# \end{align}
# $$
# b. $5\textbf{u}+3\textbf{v}-4\textbf{w}$<br>
# $$
# \begin{align}
# 5u+3v-4w\ =\ 5\left[\begin{matrix}1\\-2\\4\\\end{matrix}\right]+\ 3\left[\begin{matrix}3\\5\\1\\\end{matrix}\right]\ -\ 4\left[\begin{matrix}2\\1\\-3\\\end{matrix}\right]=\left[\begin{matrix}5\\-10\\20\\\end{matrix}\right]+\left[\begin{matrix}9\\15\\3\\\end{matrix}\right]-\left[\begin{matrix}8\\4\\-12\\\end{matrix}\right]=\ \left[\begin{matrix}6\\1\\35\\\end{matrix}\right]
# \end{align}
# $$
#
# c. $\textbf{u} \cdotp \textbf{v}$,$\textbf{v} \cdotp \textbf{w}$, $\textbf{u} \cdotp \textbf{w}$<br>
# $$
# \begin{align}
#     \textbf{u} \cdotp \textbf{v} &= (1)(3) + (-2)(5) + (4)(1) = 3 - 10 + 4 = -3 \\
#     \textbf{v} \cdotp \textbf{w} &= (3)(2) + (5)(1) + (1)(-3) = 6 + 5 - 3 = 8 \\
#     \textbf{u} \cdotp \textbf{w} &= (1)(2) + (-2)(1) + (4)(-3) = 2 - 2 - 12 = -12
# \end{align}
# $$
#
#
# d. ||$\textbf{u}$||, ||$\textbf{v}$||, ||$\textbf{w}$||<br>
# $$
# \begin{align}
#     ||\textbf{u}|| &= \sqrt{1^2 + (-2)^2 + 4^2} = \sqrt{1 + 4 + 16} = \sqrt{21} \\
#     ||\textbf{v}|| &= \sqrt{3^2 + 5^2 + 1^2} = \sqrt{9 + 25 + 1} = \sqrt{35} \\
#     ||\textbf{w}|| &= \sqrt{2^2 + 1^2 + (-3)^2} = \sqrt{4 + 1 + 9} = \sqrt{14}
# \end{align}
# $$
#
# e. If $\theta$ is the angle between $\textbf{u}$  and   $\textbf{v}$, find $\cos{\theta}$.<br>
# $$
# \begin{align}
#     cos\ \theta &= \frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}||\ ||\textbf{v}||} \\
#         &= \frac{(1)(3) + (-2)(5) + (4)(1)}{\sqrt{1^2 + (-2)^2 + 4^2}\sqrt{3^2 + 5^2 + 1^2}} \\
#         &= -\frac{3}{\sqrt{21}\sqrt{35}}
# \end{align}
# $$
#
#
# f. If $\alpha$ is the angle between $\textbf{v}$  and   $\textbf{w}$, find $\cos{\alpha}$.<br>
# $$
# \begin{align}
#     cos\ \alpha &= \frac{\textbf{v} \cdotp \textbf{w}}{||\textbf{v}||\ ||\textbf{w}||} \\
#         &= \frac{(3)(2) + (5)(1) + (1)(-3)}{\sqrt{3^2 + 5^2 + 1^2}\sqrt{2^2 + 1^2 + (-3)^2}} \\
#         &= \frac{8}{\sqrt{35}\sqrt{14}}
# \end{align}
# $$
#
#
# g. If $\beta$ is the angle between $\textbf{u}$  and   $\textbf{w}$, find $\cos{\beta}$.<br>
# $$
# \begin{align}
#     cos\ \beta &= \frac{\textbf{u} \cdotp \textbf{w}}{||\textbf{u}||\ ||\textbf{w}||} \\
#         &= \frac{(1)(2) + (-2)(1) + (4)(-3)}{\sqrt{1^2 + (-2)^2 + 4^2}\sqrt{2^2 + 1^2 + (-3)^2}} \\
#         &= -\frac{12}{\sqrt{21}\sqrt{14}}
# \end{align}
# $$
#
# h. Find $d(\textbf{u},\textbf{v})$.<br>
# $$
# \begin{align}
#     d(\textbf{u}, \textbf{v}) &= ||\textbf{u} - \textbf{v}|| \\
#         &= \sqrt{(1 - 3)^2 + (-2 - 5)^2 + (4 - 1)^2} \\
#         &= \sqrt{(-2)^2 + (-7)^2 + (3)^2} \\
#         &= \sqrt{62}
# \end{align}
# $$
#
# i. Find $d(\textbf{w},\textbf{v})$.<br>
# $$
# \begin{align}
#     d(\textbf{w},\textbf{v}) &= ||\textbf{w} - \textbf{v}|| \\
#         &= \sqrt{(2 - 3)^2 + (1 - 5)^2 + (-3 - 1)^2} \\
#         &= \sqrt{(-1)^2 + (-4)^2 + (-4)^2} \\
#         &= \sqrt{33}
# \end{align}
# $$
#
# j. Find $d(\textbf{u},\textbf{w})$. <br>
# $$
# \begin{align}
#     d(\textbf{u}, \textbf{w}) &= ||\textbf{u} - \textbf{w}|| \\
#         &= \sqrt{(1 - 2)^2 + (-2 - 1)^2 + (4 - (-3))^2} \\
#         &= \sqrt{(-1)^2 + (-3)^2 + (7)^2} \\
#         &= \sqrt{59}
# \end{align}
# $$
#
#
# k. Find $proj(\textbf{u},\textbf{v})$.<br>
# $$
# \begin{align}
#     proj(\textbf{u},\textbf{v}) &= \frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{v}||^2}\textbf{v} \\
#         &= \frac{-3}{\sqrt{3^2 + 5^2 + 1^2}^2}(3, 5, 1) \\
#         &= \frac{-3}{\sqrt{9 + 25 + 1}^2}(3, 5, 1) \\
#         &= \frac{-3}{\sqrt{35}^2}(3, 5, 1) \\
#         &= \frac{-3}{35}(3, 5, 1) \\
#         &= (-\frac{9}{35},-\frac{3}{7},-\frac{3}{35})
# \end{align}
# $$
#
# l. Find $proj(\textbf{w},\textbf{v})$.<br>
# $$
# \begin{align}
#     proj(\textbf{w},\textbf{v}) &= \frac{\textbf{w} \cdotp \textbf{v}}{||\textbf{v}||^2}\textbf{v} \\
#         &= \frac{8}{\sqrt{3^2 + 5^2 + 1^2}^2}(3, 5, 1) \\
#         &= \frac{8}{\sqrt{9 + 25 + 1}^2}(3, 5, 1) \\
#         &= \frac{8}{\sqrt{35}^2}(3, 5, 1) \\
#         &= \frac{8}{35}(3, 5, 1) \\
#         &= (\frac{24}{35},\frac{8}{7},\frac{8}{35})
# \end{align}
# $$
#
#
# m. Find $proj(\textbf{u},\textbf{w})$. <br>
# $$
# \begin{align}
#     proj(\textbf{u},\textbf{w}) &= \frac{\textbf{u} \cdotp \textbf{w}}{||\textbf{w}||^2}\textbf{w} \\
#         &= \frac{-12}{\sqrt{2^2 + 1^2 + (-3)^2}^2}(2, 1, -3) \\
#         &= \frac{-12}{\sqrt{4 + 1 + 9}^2}(2, 1, -3) \\
#         &= \frac{-12}{\sqrt{14}^2}(2, 1, -3) \\
#         &= \frac{-12}{14}(2, 1, -3) \\
#         &= \frac{-6}{7}(2, 1, -3) \\
#         &= (-\frac{12}{7},-\frac{6}{7},\frac{18}{7})
# \end{align}
# $$

# %% [markdown]
# #### Pythonic Solution

# %%
import numpy as np

u = np.array([1, -2, 4]) 
v = np.array([3,5,1])  
w = np.array([2,1,-3])

print("Answers:")
print("a. 3u - 2v: ", (3*u) - (2*v))
print("b.5𝐮 + 3𝐯 − 4𝐰: ", (5*u) + (3*v) - (4*w))

print("c. u.v =", u.dot(v))
print("   v.w = ", v.dot(w))
print("   u.w =", u.dot(w))

print("d. ||u||: ", np.sqrt(u.dot(u)))
print("   ||v||: ", np.sqrt(v.dot(v)))
print("   ||w||: ", np.sqrt(w.dot(w)))

print("e. Angle between u and v: ", u.dot(v)/(np.linalg.norm(u)*np.linalg.norm(v)))
print("f. Angle between v and w: ", v.dot(w)/(np.linalg.norm(v)*np.linalg.norm(w)))
print("g. Angle between u and w: ", u.dot(w)/(np.linalg.norm(u)*np.linalg.norm(w)))

print("h. d(u,v): ", np.linalg.norm(u-v))
print("i. d(w,v): ", np.linalg.norm(w-v))
print("j. d(u,w): ", np.linalg.norm(u-w))

print("k. proj(u,v); ", u.dot(v)*v/(np.linalg.norm(v)**2))
print("l. proj(w,v): ", w.dot(v)*v/(np.linalg.norm(v)**2))
print("m. proj(u,w): ", u.dot(w)*v/(np.linalg.norm(w)**2))
# Out:
# Answers:
# a. 3u - 2v:  [ -3 -16  10]
# b.5𝐮 + 3𝐯 − 4𝐰:  [ 6  1 35]
# c. u.v = -3
#    v.w =  8
#    u.w = -12
# d. ||u||:  4.58257569495584
#    ||v||:  5.916079783099616
#    ||w||:  3.7416573867739413
# e. Angle between u and v:  -0.11065666703449763
# f. Angle between v and w:  0.36140316116210053
# g. Angle between u and w:  -0.6998542122237653
# h. d(u,v):  7.874007874011811
# i. d(w,v):  5.744562646538029
# j. d(u,w):  7.681145747868608
# k. proj(u,v);  [-0.25714286 -0.42857143 -0.08571429]
# l. proj(w,v):  [0.68571429 1.14285714 0.22857143]
# m. proj(u,w):  [-2.57142857 -4.28571429 -0.85714286]

# %% [markdown]
# 2. Repeat problem 1 with the following column vectors:
# \begin{align}
#     \textbf{u} &= \begin{bmatrix}
#            1 \\
#            3 \\
#            -4
#          \end{bmatrix}, \textbf{v} = \begin{bmatrix}
#            2 \\
#            1 \\
#            5
#          \end{bmatrix}, \textbf{w} = \begin{bmatrix}
#            3 \\
#            -2 \\
#            6
#          \end{bmatrix}
#   \end{align}
# <br>

# %% [markdown]
# #### Manual Solution No. 2
# 1. Let $\textbf{u} = (1, 3, -4)$ and $\textbf{v} = (2, 1, 5)$ $\textbf{w} = (3,-2,-6)$ find:<br>
# a. $3\textbf{u}-2\textbf{v}$<br>
# $$
# \begin{align}
# 3u\ -\ 2v\ =\ 3\left[\begin{matrix}1\\3\\-4\\\end{matrix}\right]-\ 2\left[\begin{matrix}2\\1\\5\\\end{matrix}\right]\ =\ \left[\begin{matrix}3\\9\\-12\\\end{matrix}\right]-\ \left[\begin{matrix}4\\1\\10\\\end{matrix}\right]\ =\ \left[\begin{matrix}-1\\7\\-22\\\end{matrix}\right]
# \end{align}
# $$
#
# b. $5\textbf{u}+3\textbf{v}-4\textbf{w}$<br>
# $$
# \begin{align}
# 5u+3v-4w\ =\ 5\left[\begin{matrix}1\\3\\-4\\\end{matrix}\right]+\ 3\left[\begin{matrix}2\\1\\5\\\end{matrix}\right]\ -\ 4\left[\begin{matrix}3\\-2\\6\\\end{matrix}\right]=\left[\begin{matrix}5\\15\\-20\\\end{matrix}\right]+\left[\begin{matrix}6\\3\\15\\\end{matrix}\right]-\left[\begin{matrix}12\\-8\\24\\\end{matrix}\right]=\ \left[\begin{matrix}-1\\6\\-29\\\end{matrix}\right]
# \end{align}
# $$
#
# c. $\textbf{u} \cdotp \textbf{v}$,$\textbf{v} \cdotp \textbf{w}$, $\textbf{u} \cdotp \textbf{w}$<br>
# $$
# \begin{align}
#     \textbf{u} \cdotp \textbf{v} &= (1)(2) + (3)(1) + (-4)(5) = 2 + 3 - 20 = -15 \\
#     \textbf{v} \cdotp \textbf{w} &= (2)(3) + (1)(-2) + (5)(6) = 6 - 2 + 30 = 34 \\
#     \textbf{u} \cdotp \textbf{w} &= (1)(3) + (3)(-2) + (-4)(6) = 3 - 6 - 24 = -27
# \end{align}
# $$
#
#
# d. ||$\textbf{u}$||, ||$\textbf{v}$||, ||$\textbf{w}$||<br>
# $$
# \begin{align}
#    ||\textbf{u}|| &= \sqrt{1^2 + 3^2 + (-4)^2} = \sqrt{1 + 9 + 16} = \sqrt{26} \\
#     ||\textbf{v}|| &= \sqrt{2^2 + 1^2 + 5^2} = \sqrt{4 + 1 + 25} = \sqrt{30} \\
#     ||\textbf{w}|| &= \sqrt{3^2 + (-2)^2 + 6^2} = \sqrt{9 + 4 + 36} = \sqrt{49} = 7
# \end{align}
# $$
#
# e. If $\theta$ is the angle between $\textbf{u}$  and   $\textbf{v}$, find $\cos{\theta}$.<br>
# $$
# \begin{align}
#     cos\ \theta &= \frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}||\ ||\textbf{v}||} \\
#         &= \frac{15}{\sqrt{1^2 + 3^2 + (-4)^2}\sqrt{2^2 + 1^2 + 5^2}} \\
#         &= -\frac{15}{\sqrt{26}\sqrt{30}}
# \end{align}
# $$
#
#
# f. If $\alpha$ is the angle between $\textbf{v}$  and   $\textbf{w}$, find $\cos{\alpha}$.<br>
# $$
# \begin{align}
#       cos\ \alpha &= \frac{\textbf{v} \cdotp \textbf{w}}{||\textbf{v}||\ ||\textbf{w}||} \\
#         &= \frac{34}{\sqrt{2^2 + 1^2 + 5^2}\sqrt{3^2 + (-2)^2 + 6^2}} \\
#         &= \frac{34}{\sqrt{30}\sqrt{49}} \\
#         &= \frac{34}{7\sqrt{30}}
# \end{align}
# $$
#
#
# g. If $\beta$ is the angle between $\textbf{u}$  and   $\textbf{w}$, find $\cos{\beta}$.<br>
# $$
# \begin{align}
#     cos\ \beta &= \frac{\textbf{u} \cdotp \textbf{w}}{||\textbf{u}||\ ||\textbf{w}||} \\
#         &= \frac{27}{\sqrt{1^2 + 3^2 + (-4)^2}\sqrt{3^2 + (-2)^2 + 6^2}} \\
#         &= -\frac{27}{\sqrt{26}\sqrt{49}} \\
#         &= -\frac{27}{7\sqrt{26}}
# \end{align}
# $$
#
# h. Find $d(\textbf{u},\textbf{v})$.<br>
# $$
# \begin{align}
#      d(\textbf{u}, \textbf{v}) &= ||\textbf{u} - \textbf{v}|| \\
#         &= \sqrt{(1 - 2)^2 + (3 - 1)^2 + (-4 - 5)^2} \\
#         &= \sqrt{(-1)^2 + 2^2 + (-9)^2} \\
#         &= \sqrt{86}
# \end{align}
# $$
#
# i. Find $d(\textbf{w},\textbf{v})$.<br>
# $$
# \begin{align}
#     d(\textbf{w}, \textbf{v}) &= ||\textbf{w} - \textbf{v}|| \\
#         &= \sqrt{(3 - 2)^2 + (-2 - 1)^2 + (6 - 5)^2} \\
#         &= \sqrt{1^2 + (-3)^2 + 1^2} \\
#         &= \sqrt{11}
# \end{align}
# $$
#
# j. Find $d(\textbf{u},\textbf{w})$. <br>
# $$
# \begin{align}
#      d(\textbf{u}, \textbf{w}) &= ||\textbf{u} - \textbf{w}|| \\
#         &= \sqrt{(1 - 3)^2 + (3 - (-2))^2 + (-4 - 6)^2} \\
#         &= \sqrt{(-2)^2 + 5^2 + (-10)^2} \\
#         &= \sqrt{129}
# \end{align}
# $$
#
#
# k. Find $proj(\textbf{u},\textbf{v})$.<br>
# $$
# \begin{align}
#     proj(\textbf{u},\textbf{v}) &= \frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{v}||^2}\textbf{v} \\
#         &= \frac{-15}{\sqrt{2^2 + 1^2 + 5^2}^2}(2, 1, 5) \\
#         &= \frac{-15}{\sqrt{30}^2}(2, 1, 5) \\
#         &= \frac{-15}{30}(2, 1, 5) \\
#         &= \frac{-1}{2}(2, 1, 5) \\
#         &= (-1,-\frac{1}{2},-\frac{5}{2})
# \end{align}
# $$
#
# l. Find $proj(\textbf{w},\textbf{v})$.<br>
# $$
# \begin{align}
#     proj(\textbf{w},\textbf{v}) &= \frac{\textbf{w} \cdotp \textbf{v}}{||\textbf{v}||^2}\textbf{v} \\
#         &= \frac{34}{\sqrt{2^2 + 1^2 + 5^2}^2}(2, 1, 5) \\
#         &= \frac{34}{\sqrt{30}^2}(2, 1, 5) \\
#         &= \frac{34}{30}(2, 1, 5) \\
#         &= (\frac{34}{15},\frac{17}{15},\frac{17}{3})
# \end{align}
# $$
#
#
# m. Find $proj(\textbf{u},\textbf{w})$. <br>
# $$
# \begin{align}
#     proj(\textbf{u},\textbf{w}) &= \frac{\textbf{u} \cdotp \textbf{w}}{||\textbf{w}||^2}\textbf{w} \\
#         &= \frac{-27}{\sqrt{3^2 + (-2)^2 + 6^2}^2}(3, -2, 6) \\
#         &= \frac{-27}{\sqrt{9 + 4 + 36}^2}(3, -2, 6) \\
#         &= \frac{-27}{\sqrt{49}^2}(3, -2, 6) \\
#         &= \frac{-27}{49}(3, -2, 6) \\
#         &= (-\frac{81}{49},\frac{54}{49},-\frac{162}{49})
# \end{align}
# $$

# %%
import numpy as np

u = np.array([1, 3, -4]) 
v = np.array([2,1,5])  
w = np.array([3,-2,6])

print("Answers:")
print("a. 3u - 2v: ", (3*u) - (2*v))
print("b.5𝐮 + 3𝐯 − 4𝐰: ", (5*u) + (3*v) - (4*w))

print("c. u.v =", u.dot(v))
print("   v.w = ", v.dot(w))
print("   u.w =", u.dot(w))

print("d. ||u||: ", np.sqrt(u.dot(u)))
print("   ||v||: ", np.sqrt(v.dot(v)))
print("   ||w||: ", np.sqrt(w.dot(w)))

print("e. Angle between u and v: ", u.dot(v)/(np.linalg.norm(u)*np.linalg.norm(v)))
print("f. Angle between v and w: ", v.dot(w)/(np.linalg.norm(v)*np.linalg.norm(w)))
print("g. Angle between u and w: ", u.dot(w)/(np.linalg.norm(u)*np.linalg.norm(w)))

print("h. d(u,v): ", np.linalg.norm(u-v))
print("i. d(w,v): ", np.linalg.norm(w-v))
print("j. d(u,w): ", np.linalg.norm(u-w))

print("k. proj(u,v); ", u.dot(v)*v/(np.linalg.norm(v)**2))
print("l. proj(w,v): ", w.dot(v)*v/(np.linalg.norm(v)**2))
print("m. proj(u,w): ", u.dot(w)*v/(np.linalg.norm(w)**2))
# Out:
# Answers:
# a. 3u - 2v:  [ -1   7 -22]
# b.5𝐮 + 3𝐯 − 4𝐰:  [ -1  26 -29]
# c. u.v = -15
#    v.w =  34
#    u.w = -27
# d. ||u||:  5.0990195135927845
#    ||v||:  5.477225575051661
#    ||w||:  7.0
# e. Angle between u and v:  -0.5370861555295747
# f. Angle between v and w:  0.8867889026274118
# g. Angle between u and w:  -0.7564479498187099
# h. d(u,v):  9.273618495495704
# i. d(w,v):  3.3166247903554
# j. d(u,w):  11.357816691600547
# k. proj(u,v);  [-1.  -0.5 -2.5]
# l. proj(w,v):  [2.26666667 1.13333333 5.66666667]
# m. proj(u,w):  [-1.10204082 -0.55102041 -2.75510204]

# %% [markdown]
# 3. Let $\textbf{u} = (2,-5,4,6,-3)$ and $\textbf{v} = (5,-2,,1,-7,-4)$ $\textbf{w} = (2,1,-3)$ find:<br>
# #### Manual Solution No. 3:
# a. $4\textbf{u}-3\textbf{v}$<br>
# $$
# \begin{align}
# 4u\ -\ 3v\ =\ 3\left[\begin{matrix}2\\-5\\\begin{matrix}4\\6\\-3\\\end{matrix}\\\end{matrix}\right]\ -\ 3\left[\begin{matrix}5\\-2\\\begin{matrix}1\\-7\\-4\\\end{matrix}\\\end{matrix}\right]\ =\ \left[\begin{matrix}6\\-15\\\begin{matrix}12\\18\\-9\\\end{matrix}\\\end{matrix}\right]-\left[\begin{matrix}15\\-6\\\begin{matrix}3\\-21\\-12\\\end{matrix}\\\end{matrix}\right]\ =\ \left[\begin{matrix}-7\\-14\\\begin{matrix}13\\45\\0\\\end{matrix}\\\end{matrix}\right]
# \end{align}
# $$
#
# b. $5\textbf{u}+2\textbf{v}-2\textbf{w}$<br>
# $$
# \begin{align}
# 5u+2v-2w\ =\ 5\left[\begin{matrix}2\\-5\\\begin{matrix}4\\6\\-3\\\end{matrix}\\\end{matrix}\right]\ +2\left[\begin{matrix}5\\-2\\\begin{matrix}1\\-7\\-4\\\end{matrix}\\\end{matrix}\right]\ -2\left[\begin{matrix}3\\-2\\\begin{matrix}6\\0\\0\\\end{matrix}\\\end{matrix}\right]=\left[\begin{matrix}10\\-25\\\begin{matrix}20\\30\\-15\\\end{matrix}\\\end{matrix}\right]+\left[\begin{matrix}10\\-4\\\begin{matrix}2\\-14\\-8\\\end{matrix}\\\end{matrix}\right]-\left[\begin{matrix}4\\2\\\begin{matrix}-6\\0\\0\\\end{matrix}\\\end{matrix}\right]=\left[\begin{matrix}16\\-31\\\begin{matrix}28\\16\\-23\\\end{matrix}\\\end{matrix}\right]\
# \end{align}
# $$
#
# c. $\textbf{u} \cdotp \textbf{v}$,$\textbf{v} \cdotp \textbf{w}$, $\textbf{u} \cdotp \textbf{w}$<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# d. ||$\textbf{u}$||, ||$\textbf{v}$||, ||$\textbf{w}$||<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# e. If $\theta$ is the angle between $\textbf{u}$  and   $\textbf{v}$, find $\cos{\theta}$.<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# f. If $\alpha$ is the angle between $\textbf{v}$  and   $\textbf{w}$, find $\cos{\alpha}$.<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# g. If $\beta$ is the angle between $\textbf{u}$  and   $\textbf{w}$, find $\cos{\beta}$.<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# h. Find $d(\textbf{u},\textbf{v})$.<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# i. Find $d(\textbf{w},\textbf{v})$.<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# j. Find $d(\textbf{u},\textbf{w})$. <br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# k. Find $proj(\textbf{u},\textbf{v})$.<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# l. Find $proj(\textbf{w},\textbf{v})$.<br>
# $$
# \begin{align}
#
# \end{align}
# $$
#
# m. Find $proj(\textbf{u},\textbf{w})$. <br>
# $$
# \begin{align}
#
# \end{align}
# $$

# %% [markdown]
# #### Pythonic Solution

# %%
import numpy as np

u = np.array([2,-5,4,6,-3]) 
v = np.array([5,-2,1,-7,-4])  
w = np.array([2,1,-3,0,0])

print("Answers:")
print("a. 4u - 3v: ", (4*u) - (3*v))
print("b. 5𝐮 + 2𝐯 − 2𝐰: ", (5*u) + (2*v) - (2*w))

print("c. u.v =", u.dot(v))
print("   v.w = ", v.dot(w))
print("   u.w =", u.dot(w))

print("d. ||u||: ", np.sqrt(u.dot(u)))
print("   ||v||: ", np.sqrt(v.dot(v)))
print("   ||w||: ", np.sqrt(w.dot(w)))

print("e. Angle between u and v: ", u.dot(v)/(np.linalg.norm(u)*np.linalg.norm(v)))
print("f. Angle between v and w: ", v.dot(w)/(np.linalg.norm(v)*np.linalg.norm(w)))
print("g. Angle between u and w: ", u.dot(w)/(np.linalg.norm(u)*np.linalg.norm(w)))

print("h. d(u,v): ", np.linalg.norm(u-v))
print("i. d(w,v): ", np.linalg.norm(w-v))
print("j. d(u,w): ", np.linalg.norm(u-w))

print("k. proj(u,v); ", u.dot(v)*v/(np.linalg.norm(v)**2))
print("l. proj(w,v): ", w.dot(v)*v/(np.linalg.norm(v)**2))
print("m. proj(u,w): ", u.dot(w)*v/(np.linalg.norm(w)**2))
# Out:
# Answers:
# a. 4u - 3v:  [ -7 -14  13  45   0]
# b. 5𝐮 + 2𝐯 − 2𝐰:  [ 16 -31  28  16 -23]
# c. u.v = -6
#    v.w =  5
#    u.w = -13
# d. ||u||:  9.486832980505138
#    ||v||:  9.746794344808963
#    ||w||:  3.7416573867739413
# e. Angle between u and v:  -0.06488856845230502
# f. Angle between v and w:  0.13710212427677046
# g. Angle between u and w:  -0.3662335103823572
# h. d(u,v):  14.035668847618199
# i. d(w,v):  9.9498743710662
# j. d(u,w):  11.40175425099138
# k. proj(u,v);  [-0.31578947  0.12631579 -0.06315789  0.44210526  0.25263158]
# l. proj(w,v):  [ 0.26315789 -0.10526316  0.05263158 -0.36842105 -0.21052632]
# m. proj(u,w):  [-4.64285714  1.85714286 -0.92857143  6.5         3.71428571]

# %% [markdown]
# 4. Normalize each vector: <br>
# a. $\textbf{u}$ = (5,-7)<br>.
# b. $\textbf{v}$ = (1,2,-2,4)<br>.
# c. $\textbf{w} = (\frac{1}{2},\frac{-1}{3},\frac{3}{4})$.<br>
# <br>

# %% [markdown]
# #### Manual Solution No. 4
#
# a. $\textbf{u} = (5, -7)$
# $$
# \begin{align}
#     \textbf{u}' = \frac{\textbf{u}}{||\textbf{u}||} &= \frac{(5, -7)}{\sqrt{5^2 + (-7)^2}} \\
#         &= \frac{(5, -7)}{\sqrt{25 + 49}} \\
#         &= \frac{(5, -7)}{\sqrt{74}} \\
#         &= (\frac{5}{\sqrt{74}}, -\frac{7}{\sqrt{74}})
# \end{align}
# $$
#
#
# b. $\textbf{v} = (1, 2, -2, 4)$
# $$
# \begin{align}
#     \textbf{v}' = \frac{\textbf{v}}{||\textbf{v}||} &= \frac{(1, 2, -2, 4)}{\sqrt{1^2 + 2^2 + (-2)^2 + 4^2}} \\
#         &= \frac{(1, 2, -2, 4)}{\sqrt{1 + 4 + 4 + 16}} \\
#         &= \frac{(1, 2, -2, 4)}{\sqrt{25}} \\
#         &= \frac{(1, 2, -2, 4)}{5} \\
#         &= (\frac{1}{5}, \frac{2}{5}, -\frac{2}{5}, \frac{4}{5})
# \end{align}
# $$
#
# c. $\textbf{w} = (\frac{1}{2}, -\frac{1}{3}, \frac{3}{4})$
# $$
# \begin{align}
#     \textbf{w}' = \frac{\textbf{w}}{||\textbf{w}||} &= \frac{(\frac{1}{2}, -\frac{1}{3}, \frac{3}{4})}{\sqrt{(\frac{1}{2})^2 + (-\frac{1}{3})^2 + (\frac{3}{4})^2}} \\
#         &= \frac{(\frac{1}{2}, -\frac{1}{3}, \frac{3}{4})}{\sqrt{\frac{1}{4} + \frac{1}{9} + \frac{9}{16}}} \\
#         &= \frac{(\frac{1}{2}, -\frac{1}{3}, \frac{3}{4})}{\sqrt{\frac{36}{144} + \frac{16}{144} + \frac{81}{144}}} \\
#         &= \frac{(\frac{1}{2}, -\frac{1}{3}, \frac{3}{4})}{\sqrt{\frac{133}{144}}} \\
#         &= \frac{(\frac{1}{2}, -\frac{1}{3}, \frac{3}{4})}{\frac{\sqrt{133}}{12}} \\
#         &= \frac{12}{\sqrt{133}}(\frac{1}{2}, -\frac{1}{3}, \frac{3}{4}) \\
#         &= (\frac{6}{\sqrt{133}}, -\frac{4}{\sqrt{133}}, \frac{9}{\sqrt{133}}) \\
# \end{align}
# $$

# %%
import numpy as np

u = np.array([5, -7]) 
v = np.array([1,2,-2,4])  
w = np.array([(1/2), -(1/3), (3/4)])

print("Answers:")
print("a. Normalized u: ", u/np.sqrt(u.dot(u)))
print("b. Normalized v: ", v/np.sqrt(v.dot(v)))
print("c. Normalized w: ", w/np.sqrt(w.dot(w)))
# Out:
# Answers:
# a. Normalized u:  [ 0.58123819 -0.81373347]
# b. Normalized v:  [ 0.2  0.4 -0.4  0.8]
# c. Normalized w:  [ 0.52026598 -0.34684399  0.78039897]

# %% [markdown]
# 5. Let $\textbf{u} = (1,2,-2)$,$\textbf{v} = (3,-12,4)$ and a scalar $k = -3$: <br>
# #### Manual Solution No. 5:
# Find $||u||, ||v||, ||u+v||, ||ku||$.<br>
#
# a. $||\textbf{u}||$:
# $$
# \begin{align}
#     ||\textbf{u}|| &= \sqrt{1^2 + 2^2 + (-2)^2} \\
#         &= \sqrt{1 + 4 + 4} \\
#         &= \sqrt{9} \\
#         &= 3
# \end{align}
# $$
#
# b.  $||\textbf{v}||$:
# $$
# \begin{align}
#     ||\textbf{v}|| &= \sqrt{3^2 + (-12)^2 + 4^2} \\
#         &= \sqrt{9 + 144 + 16} \\
#         &= \sqrt{169} \\
#         &= 13
# \end{align}
# $$
#
# c.  $||\textbf{u} + \textbf{v}||$:
# $$
# \begin{align}
#     ||\textbf{u} + \textbf{v}|| &= \sqrt{(1 + 3)^2 + (2 + (-12))^2 + (-2 + 4)^2} \\
#         &= \sqrt{16 + 100 + 4} \\
#         &= \sqrt{120} \\
#         &= 2\sqrt{30}
# \end{align}
# $$
#
# d. $||k\textbf{u}||$:
# $$
# \begin{align}
#     ||k\textbf{u}|| &= \sqrt{((-3)(1))^2 + ((-3)(2))^2 + ((-3)(-2))^2} \\
#         &= \sqrt{9 + 36 + 36} \\
#         &= \sqrt{81} \\
#         &= 9
# \end{align}
# $$
#
# <br>

# %%
import numpy as np

u = np.array([1,2,-2]) 
v = np.array([3, -12,4])  
k = -3

print("Answers:")
print(" ||u||: ", np.sqrt(u.dot(u)))
print(" ||v||: ", np.sqrt(v.dot(v)))
print(" ||u + v||: ", np.linalg.norm(u+v))
print(" ||ku||: ", np.linalg.norm(k*u))
# Out:
# Answers:
#  ||u||:  3.0
#  ||v||:  13.0
#  ||u + v||:  10.954451150103322
#  ||ku||:  9.0

# %% [markdown]
# 6. Find k so that $\textbf{u}  \ and \  \textbf{v}$ are orthogonal. <br>
# a. $\textbf{u} = (3, k, -2), \textbf{v} = (6, -4, -3)$.<br>
# b. $\textbf{u} = (5,k,-4,2), \textbf{v} = (1,-3,2,2k)$.<br>
# c. $\textbf{u} = (1,7,k+2,-2), \textbf{v} = (3,, k, -3,k)$.<br>

# %% [markdown]
# #### Manual Solution No. 6
#
# a.
# $$
# \begin{align}
# uv = (3*6) + (k*(-4)) + ((-2)*(-3)) = 0 \\
# = 18 -4k + 6\\
# = 24 - 4k \\
# \text{transpose k and divide the whole equation by 4}\\
#  4k = 24\\
#  k = 6.0
# \end{align}
# $$

# %%
u = np.array([3, k, -2])
v = np.array([6, -4, -3])

# since vectors are said to be orthogonal
    # we now assume that u*v = 0
    # v+u = [18, -4k, 6]
# the sum of the vectorm if added together, is said to be 0,
    # adding all the elements and grouping by like terms we get 24 -4k = 0
    # transpose, 4k = 24
    #isolate the value of k, by dividing both sides by 4, k = 24/4
    # we now get k = 6

k = (((u[0]*v[0])+(u[2]*v[2]))/4)
print("Answers:")
print("a. k = ", k)
# Out:
# Answers:
# a. k =  6.0

# %% [markdown]
# b.
# $$
# \begin{align}
# uv = (5*1) + (k*(-3)) + ((-4)*2) + (2*2k)= 0 \\
# = 5 -3k -8 +4k\\
# = k - 3\\
# \text{transpose 3}\\
# k = 3\\
# \end{align}
# $$

# %%
u = np.array([5, k, -4, 2])
v = np.array([1, -3,2, 2*k])

# since vectors are said to be orthogonal
    # we now assume that u*v = 0
    # v+u = [5, -3k, -8, 4k]
# the sum of the vectorm if added together, is said to be 0,
    # adding all the elements and grouping by like terms we get -3+k = 0
    # transpose 3, 
    # we get, k = 3

k = (((u[0]*v[0])+(u[2]*v[2])))* -1
print("b. k =", k)
# Out:
# b. k = 3.0

# %% [markdown]
# c.
# $$
# \begin{align}
# uv = (1*3) + (7*k) + ((k+2)*(-3)) + ((-2)*k)= 0 \\
# = 3 + 7k -3k -6 -2k\\
# = 2k -3 \\
# \text{transpose 2k and divide equation by 2}\\
# 2k = 3\\
# k = \frac{3}{2}
# \end{align}
# $$

# %%
u = np.array([1,7,k+2,-2])
v = np.array([3,k,-3,k])

# since vectors are said to be orthogonal
    # we now assume that u*v = 0
    # v+u = [3, 7k, (-3k-6), -2k]
# the sum of the vectorm if added together, is said to be 0,
    # adding all the elements and grouping by like terms we get -3 + 2k = 0
    # transpose 3, 2k = 3
    #isolate the value of k, by dividing both sides by 2
    # we no get = 3/2 = 1.5

k = (3/2)
print("c. k = ", k)
# Out:
# c. k =  1.5
